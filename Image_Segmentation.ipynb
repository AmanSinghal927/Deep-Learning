# %%
# !pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (23.1)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.0.0+cu118)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (16.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.11.4

# %%
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import imageio.v3 as iio
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import tqdm
from tqdm.notebook import tqdm
import cv2
# import torchmetrics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/image_segmentation/train.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/video_810/image_3.png
#   inflating: train/video_810/image_4.png
#   inflating: train/video_810/image_5.png
#   inflating: train/video_810/image_6.png
#   inflating: train/video_810/image_7.png
#   inflating: train/video_810/image_8.png
#   inflating: train/video_810/image_9.png
#   inflating: train/video_810/mask.npy
#    creating: train/video_811/
#   inflating: train/video_811/image_0.png
#   inflating: train/video_811/image_1.png
#   inflating: train/video_811/image_10.png
#   inflating: train/video_811/image_11.png
#   inflating: train/video_811/image_12.png
#   inflating: train/video_811/image_13.png
#   inflating: train/video_811/image_14.png
#   inflating: train/video_811/image_15.png
#   inflating: train/video_811/image_16.png
#   inflating: train/video_811/image_17.png
#   inflating: train/video_811/image_18.png
#   inflating: train/video_811/image_19.png
#   inflating: train/video_811/image_2.png
#   inflating: train/video_811/image_20.png
#   inflating: train/video_811/image_21.png
#   inflating: train/video_811/image_3.png
#   inflating: train/video_811/image_4.png
#   inflating: train/video_811/image_5.png
#   inflating: train/video_811/image_6.png
#   inflating: train/video_811/image_7.png
#   inflating: train/video_811/image_8.png
#   inflating: train/video_811/image_9.png
#   inflating: train/video_811/mask.npy
#    creating: train/video_812/
#   inflating: train/video_812/image_0.png
#   inflating: train/video_812/image_1.png
#   inflating: train/video_812/image_10.png
#   inflating: train/video_812/image_11.png
#   inflating: train/video_812/image_12.png
#   inflating: train/video_812/image_13.png
#   inflating: train/video_812/image_14.png
#   inflating: train/video_812/image_15.png
#   inflating: train/video_812/image_16.png
#   inflating: train/video_812/image_17.png
#   inflating: train/video_812/image_18.png
#   inflating: train/video_812/image_19.png
#   inflating: train/video_812/image_2.png
#   inflating: train/video_812/image_20.png
#   inflating: train/video_812/image_21.png
#   inflating: train/video_812/image_3.png
#   inflating: train/video_812/image_4.png
#   inflating: train/video_812/image_5.png
#   inflating: train/video_812/image_6.png
#   inflating: train/video_812/image_7.png
#   inflating: train/video_812/image_8.png
#   inflating: train/video_812/image_9.png
#   inflating: train/video_812/mask.npy
#    creating: train/video_813/
#   inflating: train/video_813/image_0.png
#   inflating: train/video_813/image_1.png
#   inflating: train/video_813/image_10.png
#   inflating: train/video_813/image_11.png
#   inflating: train/video_813/image_12.png
#   inflating: train/video_813/image_13.png
#   inflating: train/video_813/image_14.png
#   inflating: train/video_813/image_15.png
#   inflating: train/video_813/image_16.png
#   inflating: train/video_813/image_17.png
#   inflating: train/video_813/image_18.png
#   inflating: train/video_813/image_19.png
#   inflating: train/video_813/image_2.png
#   inflating: train/video_813/image_20.png
#   inflating: train/video_813/image_21.png
#   inflating: train/video_813/image_3.png
#   inflating: train/video_813/image_4.png
#   inflating: train/video_813/image_5.png
#   inflating: train/video_813/image_6.png
#   inflating: train/video_813/image_7.png
#   inflating: train/video_813/image_8.png
#   inflating: train/video_813/image_9.png
#   inflating: train/video_813/mask.npy
#    creating: train/video_814/
#   inflating: train/video_814/image_0.png
#   inflating: train/video_814/image_1.png
#   inflating: train/video_814/image_10.png
#   inflating: train/video_814/image_11.png
#   inflating: train/video_814/image_12.png
#   inflating: train/video_814/image_13.png
#   inflating: train/video_814/image_14.png
#   inflating: train/video_814/image_15.png
#   inflating: train/video_814/image_16.png
#   inflating: train/video_814/image_17.png
#   inflating: train/video_814/image_18.png
#   inflating: train/video_814/image_19.png
#   inflating: train/video_814/image_2.png
#   inflating: train/video_814/image_20.png
#   inflating: train/video_814/image_21.png
#   inflating: train/video_814/image_3.png
#   inflating: train/video_814/image_4.png
#   inflating: train/video_814/image_5.png
#   inflating: train/video_814/image_6.png
#   inflating: train/video_814/image_7.png
#   inflating: train/video_814/image_8.png
#   inflating: train/video_814/image_9.png
#   inflating: train/video_814/mask.npy
#    creating: train/video_815/
#   inflating: train/video_815/image_0.png
#   inflating: train/video_815/image_1.png
#   inflating: train/video_815/image_10.png
#   inflating: train/video_815/image_11.png
#   inflating: train/video_815/image_12.png
#   inflating: train/video_815/image_13.png
#   inflating: train/video_815/image_14.png
#   inflating: train/video_815/image_15.png
#   inflating: train/video_815/image_16.png
#   inflating: train/video_815/image_17.png
#   inflating: train/video_815/image_18.png
#   inflating: train/video_815/image_19.png
#   inflating: train/video_815/image_2.png
#   inflating: train/video_815/image_20.png
#   inflating: train/video_815/image_21.png
#   inflating: train/video_815/image_3.png
#   inflating: train/video_815/image_4.png
#   inflating: train/video_815/image_5.png
#   inflating: train/video_815/image_6.png
#   inflating: train/video_815/image_7.png
#   inflating: train/video_815/image_8.png
#   inflating: train/video_815/image_9.png
#   inflating: train/video_815/mask.npy
#    creating: train/video_816/
#   inflating: train/video_816/image_0.png
#   inflating: train/video_816/image_1.png
#   inflating: train/video_816/image_10.png
#   inflating: train/video_816/image_11.png
#   inflating: train/video_816/image_12.png
#   inflating: train/video_816/image_13.png
#   inflating: train/video_816/image_14.png
#   inflating: train/video_816/image_15.png
#   inflating: train/video_816/image_16.png
#   inflating: train/video_816/image_17.png
#   inflating: train/video_816/image_18.png
#   inflating: train/video_816/image_19.png
#   inflating: train/video_816/image_2.png
#   inflating: train/video_816/image_20.png
#   inflating: train/video_816/image_21.png
#   inflating: train/video_816/image_3.png
#   inflating: train/video_816/image_4.png
#   inflating: train/video_816/image_5.png
#   inflating: train/video_816/image_6.png
#   inflating: train/video_816/image_7.png
#   inflating: train/video_816/image_8.png
#   inflating: train/video_816/image_9.png
#   inflating: train/video_816/mask.npy
#    creating: train/video_817/
#   inflating: train/video_817/image_0.png
#   inflating: train/video_817/image_1.png
#   inflating: train/video_817/image_10.png
#   inflating: train/video_817/image_11.png
#   inflating: train/video_817/image_12.png
#   inflating: train/video_817/image_13.png
#   inflating: train/video_817/image_14.png
#   inflating: train/video_817/image_15.png
#   inflating: train/video_817/image_16.png
#   inflating: train/video_817/image_17.png
#   inflating: train/video_817/image_18.png
#   inflating: train/video_817/image_19.png
#   inflating: train/video_817/image_2.png
#   inflating: train/video_817/image_20.png
#   inflating: train/video_817/image_21.png
#   inflating: train/video_817/image_3.png
#   inflating: train/video_817/image_4.png
#   inflating: train/video_817/image_5.png
#   inflating: train/video_817/image_6.png
#   inflating: train/video_817/image_7.png
#   inflating: train/video_817/image_8.png
#   inflating: train/video_817/image_9.png
#   inflating: train/video_817/mask.npy
#    creating: train/video_818/
#   inflating: train/video_818/image_0.png
#   inflating: train/video_818/image_1.png
#   inflating: train/video_818/image_10.png
#   inflating: train/video_818/image_11.png
#   inflating: train/video_818/image_12.png
#   inflating: train/video_818/image_13.png
#   inflating: train/video_818/image_14.png
#   inflating: train/video_818/image_15.png
#   inflating: train/video_818/image_16.png
#   inflating: train/video_818/image_17.png
#   inflating: train/video_818/image_18.png
#   inflating: train/video_818/image_19.png
#   inflating: train/video_818/image_2.png
#   inflating: train/video_818/image_20.png
#   inflating: train/video_818/image_21.png
#   inflating: train/video_818/image_3.png
#   inflating: train/video_818/image_4.png
#   inflating: train/video_818/image_5.png
#   inflating: train/video_818/image_6.png
#   inflating: train/video_818/image_7.png
#   inflating: train/video_818/image_8.png
#   inflating: train/video_818/image_9.png
#   inflating: train/video_818/mask.npy
#    creating: train/video_819/
#   inflating: train/video_819/image_0.png
#   inflating: train/video_819/image_1.png
#   inflating: train/video_819/image_10.png
#   inflating: train/video_819/image_11.png
#   inflating: train/video_819/image_12.png
#   inflating: train/video_819/image_13.png
#   inflating: train/video_819/image_14.png
#   inflating: train/video_819/image_15.png
#   inflating: train/video_819/image_16.png
#   inflating: train/video_819/image_17.png
#   inflating: train/video_819/image_18.png
#   inflating: train/video_819/image_19.png
#   inflating: train/video_819/image_2.png
#   inflating: train/video_819/image_20.png
#   inflating: train/video_819/image_21.png
#   inflating: train/video_819/image_3.png
#   inflating: train/video_819/image_4.png
#   inflating: train/video_819/image_5.png
#   inflating: train/video_819/image_6.png
#   inflating: train/video_819/image_7.png
#   inflating: train/video_819/image_8.png
#   inflating: train/video_819/image_9.png
#   inflating: train/video_819/mask.npy
#    creating: train/video_82/
#   inflating: train/video_82/image_0.png
#   inflating: train/video_82/image_1.png
#   inflating: train/video_82/image_10.png
#   inflating: train/video_82/image_11.png
#   inflating: train/video_82/image_12.png
#   inflating: train/video_82/image_13.png
#   inflating: train/video_82/image_14.png
#   inflating: train/video_82/image_15.png
#   inflating: train/video_82/image_16.png
#   inflating: train/video_82/image_17.png
#   inflating: train/video_82/image_18.png
#   inflating: train/video_82/image_19.png
#   inflating: train/video_82/image_2.png
#   inflating: train/video_82/image_20.png
#   inflating: train/video_82/image_21.png
#   inflating: train/video_82/image_3.png
#   inflating: train/video_82/image_4.png
#   inflating: train/video_82/image_5.png
#   inflating: train/video_82/image_6.png
#   inflating: train/video_82/image_7.png
#   inflating: train/video_82/image_8.png
#   inflating: train/video_82/image_9.png
#   inflating: train/video_82/mask.npy
#    creating: train/video_820/
#   inflating: train/video_820/image_0.png
#   inflating: train/video_820/image_1.png
#   inflating: train/video_820/image_10.png
#   inflating: train/video_820/image_11.png
#   inflating: train/video_820/image_12.png
#   inflating: train/video_820/image_13.png
#   inflating: train/video_820/image_14.png
#   inflating: train/video_820/image_15.png
#   inflating: train/video_820/image_16.png
#   inflating: train/video_820/image_17.png
#   inflating: train/video_820/image_18.png
#   inflating: train/video_820/image_19.png
#   inflating: train/video_820/image_2.png
#   inflating: train/video_820/image_20.png
#   inflating: train/video_820/image_21.png
#   inflating: train/video_820/image_3.png
#   inflating: train/video_820/image_4.png
#   inflating: train/video_820/image_5.png
#   inflating: train/video_820/image_6.png
#   inflating: train/video_820/image_7.png
#   inflating: train/video_820/image_8.png
#   inflating: train/video_820/image_9.png
#   inflating: train/video_820/mask.npy
#    creating: train/video_821/
#   inflating: train/video_821/image_0.png
#   inflating: train/video_821/image_1.png
#   inflating: train/video_821/image_10.png
#   inflating: train/video_821/image_11.png
#   inflating: train/video_821/image_12.png
#   inflating: train/video_821/image_13.png
#   inflating: train/video_821/image_14.png
#   inflating: train/video_821/image_15.png
#   inflating: train/video_821/image_16.png
#   inflating: train/video_821/image_17.png
#   inflating: train/video_821/image_18.png
#   inflating: train/video_821/image_19.png
#   inflating: train/video_821/image_2.png
#   inflating: train/video_821/image_20.png
#   inflating: train/video_821/image_21.png
#   inflating: train/video_821/image_3.png
#   inflating: train/video_821/image_4.png
#   inflating: train/video_821/image_5.png
#   inflating: train/video_821/image_6.png
#   inflating: train/video_821/image_7.png
#   inflating: train/video_821/image_8.png
#   inflating: train/video_821/image_9.png
#   inflating: train/video_821/mask.npy
#    creating: train/video_822/
#   inflating: train/video_822/image_0.png
#   inflating: train/video_822/image_1.png
#   inflating: train/video_822/image_10.png
#   inflating: train/video_822/image_11.png
#   inflating: train/video_822/image_12.png
#   inflating: train/video_822/image_13.png
#   inflating: train/video_822/image_14.png
#   inflating: train/video_822/image_15.png
#   inflating: train/video_822/image_16.png
#   inflating: train/video_822/image_17.png
#   inflating: train/video_822/image_18.png
#   inflating: train/video_822/image_19.png
#   inflating: train/video_822/image_2.png
#   inflating: train/video_822/image_20.png
#   inflating: train/video_822/image_21.png
#   inflating: train/video_822/image_3.png
#   inflating: train/video_822/image_4.png
#   inflating: train/video_822/image_5.png
#   inflating: train/video_822/image_6.png
#   inflating: train/video_822/image_7.png
#   inflating: train/video_822/image_8.png
#   inflating: train/video_822/image_9.png
#   inflating: train/video_822/mask.npy
#    creating: train/video_823/
#   inflating: train/video_823/image_0.png
#   inflating: train/video_823/image_1.png
#   inflating: train/video_823/image_10.png
#   inflating: train/video_823/image_11.png
#   inflating: train/video_823/image_12.png
#   inflating: train/video_823/image_13.png
#   inflating: train/video_823/image_14.png
#   inflating: train/video_823/image_15.png
#   inflating: train/video_823/image_16.png
#   inflating: train/video_823/image_17.png
#   inflating: train/video_823/image_18.png
#   inflating: train/video_823/image_19.png
#   inflating: train/video_823/image_2.png
#   inflating: train/video_823/image_20.png
#   inflating: train/video_823/image_21.png
#   inflating: train/video_823/image_3.png
#   inflating: train/video_823/image_4.png
#   inflating: train/video_823/image_5.png
#   inflating: train/video_823/image_6.png
#   inflating: train/video_823/image_7.png
#   inflating: train/video_823/image_8.png
#   inflating: train/video_823/image_9.png
#   inflating: train/video_823/mask.npy
#    creating: train/video_824/
#   inflating: train/video_824/image_0.png
#   inflating: train/video_824/image_1.png
#   inflating: train/video_824/image_10.png
#   inflating: train/video_824/image_11.png
#   inflating: train/video_824/image_12.png
#   inflating: train/video_824/image_13.png
#   inflating: train/video_824/image_14.png
#   inflating: train/video_824/image_15.png
#   inflating: train/video_824/image_16.png
#   inflating: train/video_824/image_17.png
#   inflating: train/video_824/image_18.png
#   inflating: train/video_824/image_19.png
#   inflating: train/video_824/image_2.png
#   inflating: train/video_824/image_20.png
#   inflating: train/video_824/image_21.png
#   inflating: train/video_824/image_3.png
#   inflating: train/video_824/image_4.png
#   inflating: train/video_824/image_5.png
#   inflating: train/video_824/image_6.png
#   inflating: train/video_824/image_7.png
#   inflating: train/video_824/image_8.png
#   inflating: train/video_824/image_9.png
#   inflating: train/video_824/mask.npy
#    creating: train/video_825/
#   inflating: train/video_825/image_0.png
#   inflating: train/video_825/image_1.png
#   inflating: train/video_825/image_10.png
#   inflating: train/video_825/image_11.png
#   inflating: train/video_825/image_12.png
#   inflating: train/video_825/image_13.png
#   inflating: train/video_825/image_14.png
#   inflating: train/video_825/image_15.png
#   inflating: train/video_825/image_16.png
#   inflating: train/video_825/image_17.png
#   inflating: train/video_825/image_18.png
#   inflating: train/video_825/image_19.png
#   inflating: train/video_825/image_2.png
#   inflating: train/video_825/image_20.png
#   inflating: train/video_825/image_21.png
#   inflating: train/video_825/image_3.png
#   inflating: train/video_825/image_4.png
#   inflating: train/video_825/image_5.png
#   inflating: train/video_825/image_6.png
#   inflating: train/video_825/image_7.png
#   inflating: train/video_825/image_8.png
#   inflating: train/video_825/image_9.png
#   inflating: train/video_825/mask.npy
#    creating: train/video_826/
#   inflating: train/video_826/image_0.png
#   inflating: train/video_826/image_1.png
#   inflating: train/video_826/image_10.png
#   inflating: train/video_826/image_11.png
#   inflating: train/video_826/image_12.png
#   inflating: train/video_826/image_13.png
#   inflating: train/video_826/image_14.png
#   inflating: train/video_826/image_15.png
#   inflating: train/video_826/image_16.png
#   inflating: train/video_826/image_17.png
#   inflating: train/video_826/image_18.png
#   inflating: train/video_826/image_19.png
#   inflating: train/video_826/image_2.png
#   inflating: train/video_826/image_20.png
#   inflating: train/video_826/image_21.png
#   inflating: train/video_826/image_3.png
#   inflating: train/video_826/image_4.png
#   inflating: train/video_826/image_5.png
#   inflating: train/video_826/image_6.png
#   inflating: train/video_826/image_7.png
#   inflating: train/video_826/image_8.png
#   inflating: train/video_826/image_9.png
#   inflating: train/video_826/mask.npy
#    creating: train/video_827/
#   inflating: train/video_827/image_0.png
#   inflating: train/video_827/image_1.png
#   inflating: train/video_827/image_10.png
#   inflating: train/video_827/image_11.png
#   inflating: train/video_827/image_12.png
#   inflating: train/video_827/image_13.png
#   inflating: train/video_827/image_14.png
#   inflating: train/video_827/image_15.png
#   inflating: train/video_827/image_16.png
#   inflating: train/video_827/image_17.png
#   inflating: train/video_827/image_18.png
#   inflating: train/video_827/image_19.png
#   inflating: train/video_827/image_2.png
#   inflating: train/video_827/image_20.png
#   inflating: train/video_827/image_21.png
#   inflating: train/video_827/image_3.png
#   inflating: train/video_827/image_4.png
#   inflating: train/video_827/image_5.png
#   inflating: train/video_827/image_6.png
#   inflating: train/video_827/image_7.png
#   inflating: train/video_827/image_8.png
#   inflating: train/video_827/image_9.png
#   inflating: train/video_827/mask.npy
#    creating: train/video_828/
#   inflating: train/video_828/image_0.png
#   inflating: train/video_828/image_1.png
#   inflating: train/video_828/image_10.png
#   inflating: train/video_828/image_11.png
#   inflating: train/video_828/image_12.png
#   inflating: train/video_828/image_13.png
#   inflating: train/video_828/image_14.png
#   inflating: train/video_828/image_15.png
#   inflating: train/video_828/image_16.png
#   inflating: train/video_828/image_17.png
#   inflating: train/video_828/image_18.png
#   inflating: train/video_828/image_19.png
#   inflating: train/video_828/image_2.png
#   inflating: train/video_828/image_20.png
#   inflating: train/video_828/image_21.png
#   inflating: train/video_828/image_3.png
#   inflating: train/video_828/image_4.png
#   inflating: train/video_828/image_5.png
#   inflating: train/video_828/image_6.png
#   inflating: train/video_828/image_7.png
#   inflating: train/video_828/image_8.png
#   inflating: train/video_828/image_9.png
#   inflating: train/video_828/mask.npy
#    creating: train/video_829/
#   inflating: train/video_829/image_0.png
#   inflating: train/video_829/image_1.png
#   inflating: train/video_829/image_10.png
#   inflating: train/video_829/image_11.png
#   inflating: train/video_829/image_12.png
#   inflating: train/video_829/image_13.png
#   inflating: train/video_829/image_14.png
#   inflating: train/video_829/image_15.png
#   inflating: train/video_829/image_16.png
#   inflating: train/video_829/image_17.png
#   inflating: train/video_829/image_18.png
#   inflating: train/video_829/image_19.png
#   inflating: train/video_829/image_2.png
#   inflating: train/video_829/image_20.png
#   inflating: train/video_829/image_21.png
#   inflating: train/video_829/image_3.png
#   inflating: train/video_829/image_4.png
#   inflating: train/video_829/image_5.png
#   inflating: train/video_829/image_6.png
#   inflating: train/video_829/image_7.png
#   inflating: train/video_829/image_8.png
#   inflating: train/video_829/image_9.png
#   inflating: train/video_829/mask.npy
#    creating: train/video_83/
#   inflating: train/video_83/image_0.png
#   inflating: train/video_83/image_1.png
#   inflating: train/video_83/image_10.png
#   inflating: train/video_83/image_11.png
#   inflating: train/video_83/image_12.png
#   inflating: train/video_83/image_13.png
#   inflating: train/video_83/image_14.png
#   inflating: train/video_83/image_15.png
#   inflating: train/video_83/image_16.png
#   inflating: train/video_83/image_17.png
#   inflating: train/video_83/image_18.png
#   inflating: train/video_83/image_19.png
#   inflating: train/video_83/image_2.png
#   inflating: train/video_83/image_20.png
#   inflating: train/video_83/image_21.png
#   inflating: train/video_83/image_3.png
#   inflating: train/video_83/image_4.png
#   inflating: train/video_83/image_5.png
#   inflating: train/video_83/image_6.png
#   inflating: train/video_83/image_7.png
#   inflating: train/video_83/image_8.png
#   inflating: train/video_83/image_9.png
#   inflating: train/video_83/mask.npy
#    creating: train/video_830/
#   inflating: train/video_830/image_0.png
#   inflating: train/video_830/image_1.png
#   inflating: train/video_830/image_10.png
#   inflating: train/video_830/image_11.png
#   inflating: train/video_830/image_12.png
#   inflating: train/video_830/image_13.png
#   inflating: train/video_830/image_14.png
#   inflating: train/video_830/image_15.png
#   inflating: train/video_830/image_16.png
#   inflating: train/video_830/image_17.png
#   inflating: train/video_830/image_18.png
#   inflating: train/video_830/image_19.png
#   inflating: train/video_830/image_2.png
#   inflating: train/video_830/image_20.png
#   inflating: train/video_830/image_21.png
#   inflating: train/video_830/image_3.png
#   inflating: train/video_830/image_4.png
#   inflating: train/video_830/image_5.png
#   inflating: train/video_830/image_6.png
#   inflating: train/video_830/image_7.png
#   inflating: train/video_830/image_8.png
#   inflating: train/video_830/image_9.png
#   inflating: train/video_830/mask.npy
#    creating: train/video_831/
#   inflating: train/video_831/image_0.png
#   inflating: train/video_831/image_1.png
#   inflating: train/video_831/image_10.png
#   inflating: train/video_831/image_11.png
#   inflating: train/video_831/image_12.png
#   inflating: train/video_831/image_13.png
#   inflating: train/video_831/image_14.png
#   inflating: train/video_831/image_15.png
#   inflating: train/video_831/image_16.png
#   inflating: train/video_831/image_17.png
#   inflating: train/video_831/image_18.png
#   inflating: train/video_831/image_19.png
#   inflating: train/video_831/image_2.png
#   inflating: train/video_831/image_20.png
#   inflating: train/video_831/image_21.png
#   inflating: train/video_831/image_3.png
#   inflating: train/video_831/image_4.png
#   inflating: train/video_831/image_5.png
#   inflating: train/video_831/image_6.png
#   inflating: train/video_831/image_7.png
#   inflating: train/video_831/image_8.png
#   inflating: train/video_831/image_9.png
#   inflating: train/video_831/mask.npy
#    creating: train/video_832/
#   inflating: train/video_832/image_0.png
#   inflating: train/video_832/image_1.png
#   inflating: train/video_832/image_10.png
#   inflating: train/video_832/image_11.png
#   inflating: train/video_832/image_12.png
#   inflating: train/video_832/image_13.png
#   inflating: train/video_832/image_14.png
#   inflating: train/video_832/image_15.png
#   inflating: train/video_832/image_16.png
#   inflating: train/video_832/image_17.png
#   inflating: train/video_832/image_18.png
#   inflating: train/video_832/image_19.png
#   inflating: train/video_832/image_2.png
#   inflating: train/video_832/image_20.png
#   inflating: train/video_832/image_21.png
#   inflating: train/video_832/image_3.png
#   inflating: train/video_832/image_4.png
#   inflating: train/video_832/image_5.png
#   inflating: train/video_832/image_6.png
#   inflating: train/video_832/image_7.png
#   inflating: train/video_832/image_8.png
#   inflating: train/video_832/image_9.png
#   inflating: train/video_832/mask.npy
#    creating: train/video_833/
#   inflating: train/video_833/image_0.png
#   inflating: train/video_833/image_1.png
#   inflating: train/video_833/image_10.png
#   inflating: train/video_833/image_11.png
#   inflating: train/video_833/image_12.png
#   inflating: train/video_833/image_13.png
#   inflating: train/video_833/image_14.png
#   inflating: train/video_833/image_15.png
#   inflating: train/video_833/image_16.png
#   inflating: train/video_833/image_17.png
#   inflating: train/video_833/image_18.png
#   inflating: train/video_833/image_19.png
#   inflating: train/video_833/image_2.png
#   inflating: train/video_833/image_20.png
#   inflating: train/video_833/image_21.png
#   inflating: train/video_833/image_3.png
#   inflating: train/video_833/image_4.png
#   inflating: train/video_833/image_5.png
#   inflating: train/video_833/image_6.png
#   inflating: train/video_833/image_7.png
#   inflating: train/video_833/image_8.png
#   inflating: train/video_833/image_9.png
#   inflating: train/video_833/mask.npy
#    creating: train/video_834/
#   inflating: train/video_834/image_0.png
#   inflating: train/video_834/image_1.png
#   inflating: train/video_834/image_10.png
#   inflating: train/video_834/image_11.png
#   inflating: train/video_834/image_12.png
#   inflating: train/video_834/image_13.png
#   inflating: train/video_834/image_14.png
#   inflating: train/video_834/image_15.png
#   inflating: train/video_834/image_16.png
#   inflating: train/video_834/image_17.png
#   inflating: train/video_834/image_18.png
#   inflating: train/video_834/image_19.png
#   inflating: train/video_834/image_2.png
#   inflating: train/video_834/image_20.png
#   inflating: train/video_834/image_21.png
#   inflating: train/video_834/image_3.png
#   inflating: train/video_834/image_4.png
#   inflating: train/video_834/image_5.png
#   inflating: train/video_834/image_6.png
#   inflating: train/video_834/image_7.png
#   inflating: train/video_834/image_8.png
#   inflating: train/video_834/image_9.png
#   inflating: train/video_834/mask.npy
#    creating: train/video_835/
#   inflating: train/video_835/image_0.png
#   inflating: train/video_835/image_1.png
#   inflating: train/video_835/image_10.png
#   inflating: train/video_835/image_11.png
#   inflating: train/video_835/image_12.png
#   inflating: train/video_835/image_13.png
#   inflating: train/video_835/image_14.png
#   inflating: train/video_835/image_15.png
#   inflating: train/video_835/image_16.png
#   inflating: train/video_835/image_17.png
#   inflating: train/video_835/image_18.png
#   inflating: train/video_835/image_19.png
#   inflating: train/video_835/image_2.png
#   inflating: train/video_835/image_20.png
#   inflating: train/video_835/image_21.png
#   inflating: train/video_835/image_3.png
#   inflating: train/video_835/image_4.png
#   inflating: train/video_835/image_5.png
#   inflating: train/video_835/image_6.png
#   inflating: train/video_835/image_7.png
#   inflating: train/video_835/image_8.png
#   inflating: train/video_835/image_9.png
#   inflating: train/video_835/mask.npy
#    creating: train/video_836/
#   inflating: train/video_836/image_0.png
#   inflating: train/video_836/image_1.png
#   inflating: train/video_836/image_10.png
#   inflating: train/video_836/image_11.png
#   inflating: train/video_836/image_12.png
#   inflating: train/video_836/image_13.png
#   inflating: train/video_836/image_14.png
#   inflating: train/video_836/image_15.png
#   inflating: train/video_836/image_16.png
#   inflating: train/video_836/image_17.png
#   inflating: train/video_836/image_18.png
#   inflating: train/video_836/image_19.png
#   inflating: train/video_836/image_2.png
#   inflating: train/video_836/image_20.png
#   inflating: train/video_836/image_21.png
#   inflating: train/video_836/image_3.png
#   inflating: train/video_836/image_4.png
#   inflating: train/video_836/image_5.png
#   inflating: train/video_836/image_6.png
#   inflating: train/video_836/image_7.png
#   inflating: train/video_836/image_8.png
#   inflating: train/video_836/image_9.png
#   inflating: train/video_836/mask.npy
#    creating: train/video_837/
#   inflating: train/video_837/image_0.png
#   inflating: train/video_837/image_1.png
#   inflating: train/video_837/image_10.png
#   inflating: train/video_837/image_11.png
#   inflating: train/video_837/image_12.png
#   inflating: train/video_837/image_13.png
#   inflating: train/video_837/image_14.png
#   inflating: train/video_837/image_15.png
#   inflating: train/video_837/image_16.png
#   inflating: train/video_837/image_17.png
#   inflating: train/video_837/image_18.png
#   inflating: train/video_837/image_19.png
#   inflating: train/video_837/image_2.png
#   inflating: train/video_837/image_20.png
#   inflating: train/video_837/image_21.png
#   inflating: train/video_837/image_3.png
#   inflating: train/video_837/image_4.png
#   inflating: train/video_837/image_5.png
#   inflating: train/video_837/image_6.png
#   inflating: train/video_837/image_7.png
#   inflating: train/video_837/image_8.png
#   inflating: train/video_837/image_9.png
#   inflating: train/video_837/mask.npy
#    creating: train/video_838/
#   inflating: train/video_838/image_0.png
#   inflating: train/video_838/image_1.png
#   inflating: train/video_838/image_10.png
#   inflating: train/video_838/image_11.png
#   inflating: train/video_838/image_12.png
#   inflating: train/video_838/image_13.png
#   inflating: train/video_838/image_14.png
#   inflating: train/video_838/image_15.png
#   inflating: train/video_838/image_16.png
#   inflating: train/video_838/image_17.png
#   inflating: train/video_838/image_18.png
#   inflating: train/video_838/image_19.png
#   inflating: train/video_838/image_2.png
#   inflating: train/video_838/image_20.png
#   inflating: train/video_838/image_21.png
#   inflating: train/video_838/image_3.png
#   inflating: train/video_838/image_4.png
#   inflating: train/video_838/image_5.png
#   inflating: train/video_838/image_6.png
#   inflating: train/video_838/image_7.png
#   inflating: train/video_838/image_8.png
#   inflating: train/video_838/image_9.png
#   inflating: train/video_838/mask.npy
#    creating: train/video_839/
#   inflating: train/video_839/image_0.png
#   inflating: train/video_839/image_1.png
#   inflating: train/video_839/image_10.png
#   inflating: train/video_839/image_11.png
#   inflating: train/video_839/image_12.png
#   inflating: train/video_839/image_13.png
#   inflating: train/video_839/image_14.png
#   inflating: train/video_839/image_15.png
#   inflating: train/video_839/image_16.png
#   inflating: train/video_839/image_17.png
#   inflating: train/video_839/image_18.png
#   inflating: train/video_839/image_19.png
#   inflating: train/video_839/image_2.png
#   inflating: train/video_839/image_20.png
#   inflating: train/video_839/image_21.png
#   inflating: train/video_839/image_3.png
#   inflating: train/video_839/image_4.png
#   inflating: train/video_839/image_5.png
#   inflating: train/video_839/image_6.png
#   inflating: train/video_839/image_7.png
#   inflating: train/video_839/image_8.png
#   inflating: train/video_839/image_9.png
#   inflating: train/video_839/mask.npy
#    creating: train/video_84/
#   inflating: train/video_84/image_0.png
#   inflating: train/video_84/image_1.png
#   inflating: train/video_84/image_10.png
#   inflating: train/video_84/image_11.png
#   inflating: train/video_84/image_12.png
#   inflating: train/video_84/image_13.png
#   inflating: train/video_84/image_14.png
#   inflating: train/video_84/image_15.png
#   inflating: train/video_84/image_16.png
#   inflating: train/video_84/image_17.png
#   inflating: train/video_84/image_18.png
#   inflating: train/video_84/image_19.png
#   inflating: train/video_84/image_2.png
#   inflating: train/video_84/image_20.png
#   inflating: train/video_84/image_21.png
#   inflating: train/video_84/image_3.png
#   inflating: train/video_84/image_4.png
#   inflating: train/video_84/image_5.png
#   inflating: train/video_84/image_6.png
#   inflating: train/video_84/image_7.png
#   inflating: train/video_84/image_8.png
#   inflating: train/video_84/image_9.png
#   inflating: train/video_84/mask.npy
#    creating: train/video_840/
#   inflating: train/video_840/image_0.png
#   inflating: train/video_840/image_1.png
#   inflating: train/video_840/image_10.png
#   inflating: train/video_840/image_11.png
#   inflating: train/video_840/image_12.png
#   inflating: train/video_840/image_13.png
#   inflating: train/video_840/image_14.png
#   inflating: train/video_840/image_15.png
#   inflating: train/video_840/image_16.png
#   inflating: train/video_840/image_17.png
#   inflating: train/video_840/image_18.png
#   inflating: train/video_840/image_19.png
#   inflating: train/video_840/image_2.png
#   inflating: train/video_840/image_20.png
#   inflating: train/video_840/image_21.png
#   inflating: train/video_840/image_3.png
#   inflating: train/video_840/image_4.png
#   inflating: train/video_840/image_5.png
#   inflating: train/video_840/image_6.png
#   inflating: train/video_840/image_7.png
#   inflating: train/video_840/image_8.png
#   inflating: train/video_840/image_9.png
#   inflating: train/video_840/mask.npy
#    creating: train/video_841/
#   inflating: train/video_841/image_0.png
#   inflating: train/video_841/image_1.png
#   inflating: train/video_841/image_10.png
#   inflating: train/video_841/image_11.png
#   inflating: train/video_841/image_12.png
#   inflating: train/video_841/image_13.png
#   inflating: train/video_841/image_14.png
#   inflating: train/video_841/image_15.png
#   inflating: train/video_841/image_16.png
#   inflating: train/video_841/image_17.png
#   inflating: train/video_841/image_18.png
#   inflating: train/video_841/image_19.png
#   inflating: train/video_841/image_2.png
#   inflating: train/video_841/image_20.png
#   inflating: train/video_841/image_21.png
#   inflating: train/video_841/image_3.png
#   inflating: train/video_841/image_4.png
#   inflating: train/video_841/image_5.png
#   inflating: train/video_841/image_6.png
#   inflating: train/video_841/image_7.png
#   inflating: train/video_841/image_8.png
#   inflating: train/video_841/image_9.png
#   inflating: train/video_841/mask.npy
#    creating: train/video_842/
#   inflating: train/video_842/image_0.png
#   inflating: train/video_842/image_1.png
#   inflating: train/video_842/image_10.png
#   inflating: train/video_842/image_11.png
#   inflating: train/video_842/image_12.png
#   inflating: train/video_842/image_13.png
#   inflating: train/video_842/image_14.png
#   inflating: train/video_842/image_15.png
#   inflating: train/video_842/image_16.png
#   inflating: train/video_842/image_17.png
#   inflating: train/video_842/image_18.png
#   inflating: train/video_842/image_19.png
#   inflating: train/video_842/image_2.png
#   inflating: train/video_842/image_20.png
#   inflating: train/video_842/image_21.png
#   inflating: train/video_842/image_3.png
#   inflating: train/video_842/image_4.png
#   inflating: train/video_842/image_5.png
#   inflating: train/video_842/image_6.png
#   inflating: train/video_842/image_7.png
#   inflating: train/video_842/image_8.png
#   inflating: train/video_842/image_9.png
#   inflating: train/video_842/mask.npy
#    creating: train/video_843/
#   inflating: train/video_843/image_0.png
#   inflating: train/video_843/image_1.png
#   inflating: train/video_843/image_10.png
#   inflating: train/video_843/image_11.png
#   inflating: train/video_843/image_12.png
#   inflating: train/video_843/image_13.png
#   inflating: train/video_843/image_14.png
#   inflating: train/video_843/image_15.png
#   inflating: train/video_843/image_16.png
#   inflating: train/video_843/image_17.png
#   inflating: train/video_843/image_18.png
#   inflating: train/video_843/image_19.png
#   inflating: train/video_843/image_2.png
#   inflating: train/video_843/image_20.png
#   inflating: train/video_843/image_21.png
#   inflating: train/video_843/image_3.png
#   inflating: train/video_843/image_4.png
#   inflating: train/video_843/image_5.png
#   inflating: train/video_843/image_6.png
#   inflating: train/video_843/image_7.png
#   inflating: train/video_843/image_8.png
#   inflating: train/video_843/image_9.png
#   inflating: train/video_843/mask.npy
#    creating: train/video_844/
#   inflating: train/video_844/image_0.png
#   inflating: train/video_844/image_1.png
#   inflating: train/video_844/image_10.png
#   inflating: train/video_844/image_11.png
#   inflating: train/video_844/image_12.png
#   inflating: train/video_844/image_13.png
#   inflating: train/video_844/image_14.png
#   inflating: train/video_844/image_15.png
#   inflating: train/video_844/image_16.png
#   inflating: train/video_844/image_17.png
#   inflating: train/video_844/image_18.png
#   inflating: train/video_844/image_19.png
#   inflating: train/video_844/image_2.png
#   inflating: train/video_844/image_20.png
#   inflating: train/video_844/image_21.png
#   inflating: train/video_844/image_3.png
#   inflating: train/video_844/image_4.png
#   inflating: train/video_844/image_5.png
#   inflating: train/video_844/image_6.png
#   inflating: train/video_844/image_7.png
#   inflating: train/video_844/image_8.png
#   inflating: train/video_844/image_9.png
#   inflating: train/video_844/mask.npy
#    creating: train/video_845/
#   inflating: train/video_845/image_0.png
#   inflating: train/video_845/image_1.png
#   inflating: train/video_845/image_10.png
#   inflating: train/video_845/image_11.png
#   inflating: train/video_845/image_12.png
#   inflating: train/video_845/image_13.png
#   inflating: train/video_845/image_14.png
#   inflating: train/video_845/image_15.png
#   inflating: train/video_845/image_16.png
#   inflating: train/video_845/image_17.png
#   inflating: train/video_845/image_18.png
#   inflating: train/video_845/image_19.png
#   inflating: train/video_845/image_2.png
#   inflating: train/video_845/image_20.png
#   inflating: train/video_845/image_21.png
#   inflating: train/video_845/image_3.png
#   inflating: train/video_845/image_4.png
#   inflating: train/video_845/image_5.png
#   inflating: train/video_845/image_6.png
#   inflating: train/video_845/image_7.png
#   inflating: train/video_845/image_8.png
#   inflating: train/video_845/image_9.png
#   inflating: train/video_845/mask.npy
#    creating: train/video_846/
#   inflating: train/video_846/image_0.png
#   inflating: train/video_846/image_1.png
#   inflating: train/video_846/image_10.png
#   inflating: train/video_846/image_11.png
#   inflating: train/video_846/image_12.png
#   inflating: train/video_846/image_13.png
#   inflating: train/video_846/image_14.png
#   inflating: train/video_846/image_15.png
#   inflating: train/video_846/image_16.png
#   inflating: train/video_846/image_17.png
#   inflating: train/video_846/image_18.png
#   inflating: train/video_846/image_19.png
#   inflating: train/video_846/image_2.png
#   inflating: train/video_846/image_20.png
#   inflating: train/video_846/image_21.png
#   inflating: train/video_846/image_3.png
#   inflating: train/video_846/image_4.png
#   inflating: train/video_846/image_5.png
#   inflating: train/video_846/image_6.png
#   inflating: train/video_846/image_7.png
#   inflating: train/video_846/image_8.png
#   inflating: train/video_846/image_9.png
#   inflating: train/video_846/mask.npy
#    creating: train/video_847/
#   inflating: train/video_847/image_0.png
#   inflating: train/video_847/image_1.png
#   inflating: train/video_847/image_10.png
#   inflating: train/video_847/image_11.png
#   inflating: train/video_847/image_12.png
#   inflating: train/video_847/image_13.png
#   inflating: train/video_847/image_14.png
#   inflating: train/video_847/image_15.png
#   inflating: train/video_847/image_16.png
#   inflating: train/video_847/image_17.png
#   inflating: train/video_847/image_18.png
#   inflating: train/video_847/image_19.png
#   inflating: train/video_847/image_2.png
#   inflating: train/video_847/image_20.png
#   inflating: train/video_847/image_21.png
#   inflating: train/video_847/image_3.png
#   inflating: train/video_847/image_4.png
#   inflating: train/video_847/image_5.png
#   inflating: train/video_847/image_6.png
#   inflating: train/video_847/image_7.png
#   inflating: train/video_847/image_8.png
#   inflating: train/video_847/image_9.png
#   inflating: train/video_847/mask.npy
#    creating: train/video_848/
#   inflating: train/video_848/image_0.png
#   inflating: train/video_848/image_1.png
#   inflating: train/video_848/image_10.png
#   inflating: train/video_848/image_11.png
#   inflating: train/video_848/image_12.png
#   inflating: train/video_848/image_13.png
#   inflating: train/video_848/image_14.png
#   inflating: train/video_848/image_15.png
#   inflating: train/video_848/image_16.png
#   inflating: train/video_848/image_17.png
#   inflating: train/video_848/image_18.png
#   inflating: train/video_848/image_19.png
#   inflating: train/video_848/image_2.png
#   inflating: train/video_848/image_20.png
#   inflating: train/video_848/image_21.png
#   inflating: train/video_848/image_3.png
#   inflating: train/video_848/image_4.png
#   inflating: train/video_848/image_5.png
#   inflating: train/video_848/image_6.png
#   inflating: train/video_848/image_7.png
#   inflating: train/video_848/image_8.png
#   inflating: train/video_848/image_9.png
#   inflating: train/video_848/mask.npy
#    creating: train/video_849/
#   inflating: train/video_849/image_0.png
#   inflating: train/video_849/image_1.png
#   inflating: train/video_849/image_10.png
#   inflating: train/video_849/image_11.png
#   inflating: train/video_849/image_12.png
#   inflating: train/video_849/image_13.png
#   inflating: train/video_849/image_14.png
#   inflating: train/video_849/image_15.png
#   inflating: train/video_849/image_16.png
#   inflating: train/video_849/image_17.png
#   inflating: train/video_849/image_18.png
#   inflating: train/video_849/image_19.png
#   inflating: train/video_849/image_2.png
#   inflating: train/video_849/image_20.png
#   inflating: train/video_849/image_21.png
#   inflating: train/video_849/image_3.png
#   inflating: train/video_849/image_4.png
#   inflating: train/video_849/image_5.png
#   inflating: train/video_849/image_6.png
#   inflating: train/video_849/image_7.png
#   inflating: train/video_849/image_8.png
#   inflating: train/video_849/image_9.png
#   inflating: train/video_849/mask.npy
#    creating: train/video_85/
#   inflating: train/video_85/image_0.png
#   inflating: train/video_85/image_1.png
#   inflating: train/video_85/image_10.png
#   inflating: train/video_85/image_11.png
#   inflating: train/video_85/image_12.png
#   inflating: train/video_85/image_13.png
#   inflating: train/video_85/image_14.png
#   inflating: train/video_85/image_15.png
#   inflating: train/video_85/image_16.png
#   inflating: train/video_85/image_17.png
#   inflating: train/video_85/image_18.png
#   inflating: train/video_85/image_19.png
#   inflating: train/video_85/image_2.png
#   inflating: train/video_85/image_20.png
#   inflating: train/video_85/image_21.png
#   inflating: train/video_85/image_3.png
#   inflating: train/video_85/image_4.png
#   inflating: train/video_85/image_5.png
#   inflating: train/video_85/image_6.png
#   inflating: train/video_85/image_7.png
#   inflating: train/video_85/image_8.png
#   inflating: train/video_85/image_9.png
#   inflating: train/video_85/mask.npy
#    creating: train/video_850/
#   inflating: train/video_850/image_0.png
#   inflating: train/video_850/image_1.png
#   inflating: train/video_850/image_10.png
#   inflating: train/video_850/image_11.png
#   inflating: train/video_850/image_12.png
#   inflating: train/video_850/image_13.png
#   inflating: train/video_850/image_14.png
#   inflating: train/video_850/image_15.png
#   inflating: train/video_850/image_16.png
#   inflating: train/video_850/image_17.png
#   inflating: train/video_850/image_18.png
#   inflating: train/video_850/image_19.png
#   inflating: train/video_850/image_2.png
#   inflating: train/video_850/image_20.png
#   inflating: train/video_850/image_21.png
#   inflating: train/video_850/image_3.png
#   inflating: train/video_850/image_4.png
#   inflating: train/video_850/image_5.png
#   inflating: train/video_850/image_6.png
#   inflating: train/video_850/image_7.png
#   inflating: train/video_850/image_8.png
#   inflating: train/video_850/image_9.png
#   inflating: train/video_850/mask.npy
#    creating: train/video_851/
#   inflating: train/video_851/image_0.png
#   inflating: train/video_851/image_1.png
#   inflating: train/video_851/image_10.png
#   inflating: train/video_851/image_11.png
#   inflating: train/video_851/image_12.png
#   inflating: train/video_851/image_13.png
#   inflating: train/video_851/image_14.png
#   inflating: train/video_851/image_15.png
#   inflating: train/video_851/image_16.png
#   inflating: train/video_851/image_17.png
#   inflating: train/video_851/image_18.png
#   inflating: train/video_851/image_19.png
#   inflating: train/video_851/image_2.png
#   inflating: train/video_851/image_20.png
#   inflating: train/video_851/image_21.png
#   inflating: train/video_851/image_3.png
#   inflating: train/video_851/image_4.png
#   inflating: train/video_851/image_5.png
#   inflating: train/video_851/image_6.png
#   inflating: train/video_851/image_7.png
#   inflating: train/video_851/image_8.png
#   inflating: train/video_851/image_9.png
#   inflating: train/video_851/mask.npy
#    creating: train/video_852/
#   inflating: train/video_852/image_0.png
#   inflating: train/video_852/image_1.png
#   inflating: train/video_852/image_10.png
#   inflating: train/video_852/image_11.png
#   inflating: train/video_852/image_12.png
#   inflating: train/video_852/image_13.png
#   inflating: train/video_852/image_14.png
#   inflating: train/video_852/image_15.png
#   inflating: train/video_852/image_16.png
#   inflating: train/video_852/image_17.png
#   inflating: train/video_852/image_18.png
#   inflating: train/video_852/image_19.png
#   inflating: train/video_852/image_2.png
#   inflating: train/video_852/image_20.png
#   inflating: train/video_852/image_21.png
#   inflating: train/video_852/image_3.png
#   inflating: train/video_852/image_4.png
#   inflating: train/video_852/image_5.png
#   inflating: train/video_852/image_6.png
#   inflating: train/video_852/image_7.png
#   inflating: train/video_852/image_8.png
#   inflating: train/video_852/image_9.png
#   inflating: train/video_852/mask.npy
#    creating: train/video_853/
#   inflating: train/video_853/image_0.png
#   inflating: train/video_853/image_1.png
#   inflating: train/video_853/image_10.png
#   inflating: train/video_853/image_11.png
#   inflating: train/video_853/image_12.png
#   inflating: train/video_853/image_13.png
#   inflating: train/video_853/image_14.png
#   inflating: train/video_853/image_15.png
# ...
#   inflating: train/video_985/image_17.png
#   inflating: train/video_985/image_18.png
#   inflating: train/video_985/image_19.png
#   inflating: train/video_985/image_2.png
#   inflating: train/video_985/image_20.png
#   inflating: train/video_985/image_21.png
#   inflating: train/video_985/image_3.png
#   inflating: train/video_985/image_4.png
#   inflating: train/video_985/image_5.png
#   inflating: train/video_985/image_6.png
#   inflating: train/video_985/image_7.png
#   inflating: train/video_985/image_8.png
#   inflating: train/video_985/image_9.png
#   inflating: train/video_985/mask.npy
#    creating: train/video_986/
#   inflating: train/video_986/image_0.png
#   inflating: train/video_986/image_1.png
#   inflating: train/video_986/image_10.png
#   inflating: train/video_986/image_11.png
#   inflating: train/video_986/image_12.png
#   inflating: train/video_986/image_13.png
#   inflating: train/video_986/image_14.png
#   inflating: train/video_986/image_15.png
#   inflating: train/video_986/image_16.png
#   inflating: train/video_986/image_17.png
#   inflating: train/video_986/image_18.png
#   inflating: train/video_986/image_19.png
#   inflating: train/video_986/image_2.png
#   inflating: train/video_986/image_20.png
#   inflating: train/video_986/image_21.png
#   inflating: train/video_986/image_3.png
#   inflating: train/video_986/image_4.png
#   inflating: train/video_986/image_5.png
#   inflating: train/video_986/image_6.png
#   inflating: train/video_986/image_7.png
#   inflating: train/video_986/image_8.png
#   inflating: train/video_986/image_9.png
#   inflating: train/video_986/mask.npy
#    creating: train/video_987/
#   inflating: train/video_987/image_0.png
#   inflating: train/video_987/image_1.png
#   inflating: train/video_987/image_10.png
#   inflating: train/video_987/image_11.png
#   inflating: train/video_987/image_12.png
#   inflating: train/video_987/image_13.png
#   inflating: train/video_987/image_14.png
#   inflating: train/video_987/image_15.png
#   inflating: train/video_987/image_16.png
#   inflating: train/video_987/image_17.png
#   inflating: train/video_987/image_18.png
#   inflating: train/video_987/image_19.png
#   inflating: train/video_987/image_2.png
#   inflating: train/video_987/image_20.png
#   inflating: train/video_987/image_21.png
#   inflating: train/video_987/image_3.png
#   inflating: train/video_987/image_4.png
#   inflating: train/video_987/image_5.png
#   inflating: train/video_987/image_6.png
#   inflating: train/video_987/image_7.png
#   inflating: train/video_987/image_8.png
#   inflating: train/video_987/image_9.png
#   inflating: train/video_987/mask.npy
#    creating: train/video_988/
#   inflating: train/video_988/image_0.png
#   inflating: train/video_988/image_1.png
#   inflating: train/video_988/image_10.png
#   inflating: train/video_988/image_11.png
#   inflating: train/video_988/image_12.png
#   inflating: train/video_988/image_13.png
#   inflating: train/video_988/image_14.png
#   inflating: train/video_988/image_15.png
#   inflating: train/video_988/image_16.png
#   inflating: train/video_988/image_17.png
#   inflating: train/video_988/image_18.png
#   inflating: train/video_988/image_19.png
#   inflating: train/video_988/image_2.png
#   inflating: train/video_988/image_20.png
#   inflating: train/video_988/image_21.png
#   inflating: train/video_988/image_3.png
#   inflating: train/video_988/image_4.png
#   inflating: train/video_988/image_5.png
#   inflating: train/video_988/image_6.png
#   inflating: train/video_988/image_7.png
#   inflating: train/video_988/image_8.png
#   inflating: train/video_988/image_9.png
#   inflating: train/video_988/mask.npy
#    creating: train/video_989/
#   inflating: train/video_989/image_0.png
#   inflating: train/video_989/image_1.png
#   inflating: train/video_989/image_10.png
#   inflating: train/video_989/image_11.png
#   inflating: train/video_989/image_12.png
#   inflating: train/video_989/image_13.png
#   inflating: train/video_989/image_14.png
#   inflating: train/video_989/image_15.png
#   inflating: train/video_989/image_16.png
#   inflating: train/video_989/image_17.png
#   inflating: train/video_989/image_18.png
#   inflating: train/video_989/image_19.png
#   inflating: train/video_989/image_2.png
#   inflating: train/video_989/image_20.png
#   inflating: train/video_989/image_21.png
#   inflating: train/video_989/image_3.png
#   inflating: train/video_989/image_4.png
#   inflating: train/video_989/image_5.png
#   inflating: train/video_989/image_6.png
#   inflating: train/video_989/image_7.png
#   inflating: train/video_989/image_8.png
#   inflating: train/video_989/image_9.png
#   inflating: train/video_989/mask.npy
#    creating: train/video_99/
#   inflating: train/video_99/image_0.png
#   inflating: train/video_99/image_1.png
#   inflating: train/video_99/image_10.png
#   inflating: train/video_99/image_11.png
#   inflating: train/video_99/image_12.png
#   inflating: train/video_99/image_13.png
#   inflating: train/video_99/image_14.png
#   inflating: train/video_99/image_15.png
#   inflating: train/video_99/image_16.png
#   inflating: train/video_99/image_17.png
#   inflating: train/video_99/image_18.png
#   inflating: train/video_99/image_19.png
#   inflating: train/video_99/image_2.png
#   inflating: train/video_99/image_20.png
#   inflating: train/video_99/image_21.png
#   inflating: train/video_99/image_3.png
#   inflating: train/video_99/image_4.png
#   inflating: train/video_99/image_5.png
#   inflating: train/video_99/image_6.png
#   inflating: train/video_99/image_7.png
#   inflating: train/video_99/image_8.png
#   inflating: train/video_99/image_9.png
#   inflating: train/video_99/mask.npy
#    creating: train/video_990/
#   inflating: train/video_990/image_0.png
#   inflating: train/video_990/image_1.png
#   inflating: train/video_990/image_10.png
#   inflating: train/video_990/image_11.png
#   inflating: train/video_990/image_12.png
#   inflating: train/video_990/image_13.png
#   inflating: train/video_990/image_14.png
#   inflating: train/video_990/image_15.png
#   inflating: train/video_990/image_16.png
#   inflating: train/video_990/image_17.png
#   inflating: train/video_990/image_18.png
#   inflating: train/video_990/image_19.png
#   inflating: train/video_990/image_2.png
#   inflating: train/video_990/image_20.png
#   inflating: train/video_990/image_21.png
#   inflating: train/video_990/image_3.png
#   inflating: train/video_990/image_4.png
#   inflating: train/video_990/image_5.png
#   inflating: train/video_990/image_6.png
#   inflating: train/video_990/image_7.png
#   inflating: train/video_990/image_8.png
#   inflating: train/video_990/image_9.png
#   inflating: train/video_990/mask.npy
#    creating: train/video_991/
#   inflating: train/video_991/image_0.png
#   inflating: train/video_991/image_1.png
#   inflating: train/video_991/image_10.png
#   inflating: train/video_991/image_11.png
#   inflating: train/video_991/image_12.png
#   inflating: train/video_991/image_13.png
#   inflating: train/video_991/image_14.png
#   inflating: train/video_991/image_15.png
#   inflating: train/video_991/image_16.png
#   inflating: train/video_991/image_17.png
#   inflating: train/video_991/image_18.png
#   inflating: train/video_991/image_19.png
#   inflating: train/video_991/image_2.png
#   inflating: train/video_991/image_20.png
#   inflating: train/video_991/image_21.png
#   inflating: train/video_991/image_3.png
#   inflating: train/video_991/image_4.png
#   inflating: train/video_991/image_5.png
#   inflating: train/video_991/image_6.png
#   inflating: train/video_991/image_7.png
#   inflating: train/video_991/image_8.png
#   inflating: train/video_991/image_9.png
#   inflating: train/video_991/mask.npy
#    creating: train/video_992/
#   inflating: train/video_992/image_0.png
#   inflating: train/video_992/image_1.png
#   inflating: train/video_992/image_10.png
#   inflating: train/video_992/image_11.png
#   inflating: train/video_992/image_12.png
#   inflating: train/video_992/image_13.png
#   inflating: train/video_992/image_14.png
#   inflating: train/video_992/image_15.png
#   inflating: train/video_992/image_16.png
#   inflating: train/video_992/image_17.png
#   inflating: train/video_992/image_18.png
#   inflating: train/video_992/image_19.png
#   inflating: train/video_992/image_2.png
#   inflating: train/video_992/image_20.png
#   inflating: train/video_992/image_21.png
#   inflating: train/video_992/image_3.png
#   inflating: train/video_992/image_4.png
#   inflating: train/video_992/image_5.png
#   inflating: train/video_992/image_6.png
#   inflating: train/video_992/image_7.png
#   inflating: train/video_992/image_8.png
#   inflating: train/video_992/image_9.png
#   inflating: train/video_992/mask.npy
#    creating: train/video_993/
#   inflating: train/video_993/image_0.png
#   inflating: train/video_993/image_1.png
#   inflating: train/video_993/image_10.png
#   inflating: train/video_993/image_11.png
#   inflating: train/video_993/image_12.png
#   inflating: train/video_993/image_13.png
#   inflating: train/video_993/image_14.png
#   inflating: train/video_993/image_15.png
#   inflating: train/video_993/image_16.png
#   inflating: train/video_993/image_17.png
#   inflating: train/video_993/image_18.png
#   inflating: train/video_993/image_19.png
#   inflating: train/video_993/image_2.png
#   inflating: train/video_993/image_20.png
#   inflating: train/video_993/image_21.png
#   inflating: train/video_993/image_3.png
#   inflating: train/video_993/image_4.png
#   inflating: train/video_993/image_5.png
#   inflating: train/video_993/image_6.png
#   inflating: train/video_993/image_7.png
#   inflating: train/video_993/image_8.png
#   inflating: train/video_993/image_9.png
#   inflating: train/video_993/mask.npy
#    creating: train/video_994/
#   inflating: train/video_994/image_0.png
#   inflating: train/video_994/image_1.png
#   inflating: train/video_994/image_10.png
#   inflating: train/video_994/image_11.png
#   inflating: train/video_994/image_12.png
#   inflating: train/video_994/image_13.png
#   inflating: train/video_994/image_14.png
#   inflating: train/video_994/image_15.png
#   inflating: train/video_994/image_16.png
#   inflating: train/video_994/image_17.png
#   inflating: train/video_994/image_18.png
#   inflating: train/video_994/image_19.png
#   inflating: train/video_994/image_2.png
#   inflating: train/video_994/image_20.png
#   inflating: train/video_994/image_21.png
#   inflating: train/video_994/image_3.png
#   inflating: train/video_994/image_4.png
#   inflating: train/video_994/image_5.png
#   inflating: train/video_994/image_6.png
#   inflating: train/video_994/image_7.png
#   inflating: train/video_994/image_8.png
#   inflating: train/video_994/image_9.png
#   inflating: train/video_994/mask.npy
#    creating: train/video_995/
#   inflating: train/video_995/image_0.png
#   inflating: train/video_995/image_1.png
#   inflating: train/video_995/image_10.png
#   inflating: train/video_995/image_11.png
#   inflating: train/video_995/image_12.png
#   inflating: train/video_995/image_13.png
#   inflating: train/video_995/image_14.png
#   inflating: train/video_995/image_15.png
#   inflating: train/video_995/image_16.png
#   inflating: train/video_995/image_17.png
#   inflating: train/video_995/image_18.png
#   inflating: train/video_995/image_19.png
#   inflating: train/video_995/image_2.png
#   inflating: train/video_995/image_20.png
#   inflating: train/video_995/image_21.png
#   inflating: train/video_995/image_3.png
#   inflating: train/video_995/image_4.png
#   inflating: train/video_995/image_5.png
#   inflating: train/video_995/image_6.png
#   inflating: train/video_995/image_7.png
#   inflating: train/video_995/image_8.png
#   inflating: train/video_995/image_9.png
#   inflating: train/video_995/mask.npy
#    creating: train/video_996/
#   inflating: train/video_996/image_0.png
#   inflating: train/video_996/image_1.png
#   inflating: train/video_996/image_10.png
#   inflating: train/video_996/image_11.png
#   inflating: train/video_996/image_12.png
#   inflating: train/video_996/image_13.png
#   inflating: train/video_996/image_14.png
#   inflating: train/video_996/image_15.png
#   inflating: train/video_996/image_16.png
#   inflating: train/video_996/image_17.png
#   inflating: train/video_996/image_18.png
#   inflating: train/video_996/image_19.png
#   inflating: train/video_996/image_2.png
#   inflating: train/video_996/image_20.png
#   inflating: train/video_996/image_21.png
#   inflating: train/video_996/image_3.png
#   inflating: train/video_996/image_4.png
#   inflating: train/video_996/image_5.png
#   inflating: train/video_996/image_6.png
#   inflating: train/video_996/image_7.png
#   inflating: train/video_996/image_8.png
#   inflating: train/video_996/image_9.png
#   inflating: train/video_996/mask.npy
#    creating: train/video_997/
#   inflating: train/video_997/image_0.png
#   inflating: train/video_997/image_1.png
#   inflating: train/video_997/image_10.png
#   inflating: train/video_997/image_11.png
#   inflating: train/video_997/image_12.png
#   inflating: train/video_997/image_13.png
#   inflating: train/video_997/image_14.png
#   inflating: train/video_997/image_15.png
#   inflating: train/video_997/image_16.png
#   inflating: train/video_997/image_17.png
#   inflating: train/video_997/image_18.png
#   inflating: train/video_997/image_19.png
#   inflating: train/video_997/image_2.png
#   inflating: train/video_997/image_20.png
#   inflating: train/video_997/image_21.png
#   inflating: train/video_997/image_3.png
#   inflating: train/video_997/image_4.png
#   inflating: train/video_997/image_5.png
#   inflating: train/video_997/image_6.png
#   inflating: train/video_997/image_7.png
#   inflating: train/video_997/image_8.png
#   inflating: train/video_997/image_9.png
#   inflating: train/video_997/mask.npy
#    creating: train/video_998/
#   inflating: train/video_998/image_0.png
#   inflating: train/video_998/image_1.png
#   inflating: train/video_998/image_10.png
#   inflating: train/video_998/image_11.png
#   inflating: train/video_998/image_12.png
#   inflating: train/video_998/image_13.png
#   inflating: train/video_998/image_14.png
#   inflating: train/video_998/image_15.png
#   inflating: train/video_998/image_16.png
#   inflating: train/video_998/image_17.png
#   inflating: train/video_998/image_18.png
#   inflating: train/video_998/image_19.png
#   inflating: train/video_998/image_2.png
#   inflating: train/video_998/image_20.png
#   inflating: train/video_998/image_21.png
#   inflating: train/video_998/image_3.png
#   inflating: train/video_998/image_4.png
#   inflating: train/video_998/image_5.png
#   inflating: train/video_998/image_6.png
#   inflating: train/video_998/image_7.png
#   inflating: train/video_998/image_8.png
#   inflating: train/video_998/image_9.png
#   inflating: train/video_998/mask.npy
#    creating: train/video_999/
#   inflating: train/video_999/image_0.png
#   inflating: train/video_999/image_1.png
#   inflating: train/video_999/image_10.png
#   inflating: train/video_999/image_11.png
#   inflating: train/video_999/image_12.png
#   inflating: train/video_999/image_13.png
#   inflating: train/video_999/image_14.png
#   inflating: train/video_999/image_15.png
#   inflating: train/video_999/image_16.png
#   inflating: train/video_999/image_17.png
#   inflating: train/video_999/image_18.png
#   inflating: train/video_999/image_19.png
#   inflating: train/video_999/image_2.png
#   inflating: train/video_999/image_20.png
#   inflating: train/video_999/image_21.png
#   inflating: train/video_999/image_3.png
#   inflating: train/video_999/image_4.png
#   inflating: train/video_999/image_5.png
#   inflating: train/video_999/image_6.png
#   inflating: train/video_999/image_7.png
#   inflating: train/video_999/image_8.png
#   inflating: train/video_999/image_9.png
#   inflating: train/video_999/mask.npy

# %%
# !unzip /content/drive/MyDrive/image_segmentation/val.zip

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
device = torch.device(device)
print(device)
# Out:
# cpu

# %% [markdown]
# ## Preprare train and validation for dataset

# %%
# I want a directory of images and their maps
def vpath2ipath(train_dir):
  train_video_dir = [] # if .png
  train_video_masks = [] #if npy
  mask_order = []
  for video_nm in tqdm(os.listdir(train_dir)):
    video_path = os.path.join(train_dir, video_nm)
    mask_order.append(video_path)
    video_img = []
    for img_nm in os.listdir(video_path):
      if ("mask" not in img_nm):
        video_img.append(os.path.join(video_path,img_nm))
    video_img = sorted(video_img, key = (lambda x: int(x.split("_")[-1].split(".")[0])))
    train_video_dir.extend(video_img)
  return train_video_dir, mask_order
# Probably handle masks in the training loop

# %%
train_dir = "/content/train"
train_video_dir, mask_order_train = vpath2ipath(train_dir)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
val_dir = "/content/val"
val_video_dir, mask_order_val = vpath2ipath(val_dir)

# %%
# Video output
import cv2
import os

image_folder = '/content/train/video_0'
output_gif = 'output_video.gif'
images = [i for i in os.listdir(image_folder) if 'mask' not in i]

# %%
images = sorted(images, key = (lambda x: int(x.split("_")[-1].split(".")[0])))

# Load images into a list
image_list = [Image.open(os.path.join(image_folder, img)) for img in images]

# Save images as an animated GIF
image_list[0].save(output_gif, save_all=True, append_images=image_list[1:], duration=100, loop=0)

# %%
mask = np.load('/content/train/video_0/mask.npy')

# %%
plt.imshow(mask[21])

# %% [markdown]
# ## Calculate mean and standard deviation

# %%
# def compute_mean_std(image_files):
#     # Get a list of image file paths
#     # Initialize variables for mean and standard deviation calculation
#     num_images = len(image_files)
#     channel_sum = np.zeros(3)
#     channel_squared_sum = np.zeros(3)

#     # Iterate over images
#     for image_file in tqdm(image_files):
#         # Open image and convert to tensor
#         image = Image.open(image_file)
#         image_tensor = ToTensor()(image).numpy()

#         # Accumulate the sum and squared sum of pixel values for each channel
#         channel_sum += np.sum(image_tensor, axis=(1, 2))
#         channel_squared_sum += np.sum(np.square(image_tensor), axis=(1, 2))

#     # Calculate mean and standard deviation
#     mean = channel_sum / (num_images * image_tensor.shape[1] * image_tensor.shape[2])
#     std = np.sqrt(channel_squared_sum / (num_images * image_tensor.shape[1] * image_tensor.shape[2]) - np.square(mean))

#     return mean, std

# # Replace 'path_to_your_image_folder' with the correct path to your image folder
# mean, std = compute_mean_std(img_list)
# print(f"Mean: {mean}")
# print(f"Standard Deviation: {std}")

# %% [markdown]
# ## Prepare dataset for dataloader

# %%
class UNetDataset(Dataset):
    def __init__(self, img_list, transform1=None, transform2=None):
        self.img_list = img_list
        self.transform1 = transform1
        self.transform2 = transform2

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):
        img_name = self.img_list[idx]
        image = Image.open(img_name).convert("RGB")

        mask_dir = os.path.join("/".join(img_name.split("/")[:-1]), 'mask.npy')
        mask_idx = int("".join(img_name.split("/")[-1]).split(".")[0].split("_")[1])
        mask = np.load(mask_dir)[mask_idx]

        # Resize for UNet model
        image_np = np.array(image)
        image_np = cv2.copyMakeBorder(image_np, top=0, bottom=0, left=0, right=16, borderType=cv2.BORDER_CONSTANT, value=0)


        # Resize and pad mask
        mask = cv2.copyMakeBorder(mask, top=0, bottom=0, left=0, right=16, borderType=cv2.BORDER_CONSTANT, value=0)



        if self.transform1:
            image = self.transform1(Image.fromarray(image_np))
        mask = torch.tensor(mask, dtype=torch.long) # this transform won't have any to tensor torch.tensor()
        return image, mask

# %%
transform1 = transforms.Compose([
    transforms.RandomRotation(10),  # Data augmentation: random rotation
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),  # Data augmentation: color jitter
    transforms.ToTensor(),  # Convert image to tensor
    # transforms.Normalize(mean = [0.50620994, 0.50456696, 0.50085988], std = [0.05694261, 0.05674587, 0.06141094]),
])

# %%
# train loader
batch_size = 32
img_list = train_video_dir
dataset = UNetDataset(img_list, transform1)
train_dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
# validation loader
batch_size = 32
img_list = val_video_dir
dataset = UNetDataset(img_list, transform1)
val_dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
# Testing out train_dataloader
for _, (image, mask) in enumerate(train_dataloader):
  break

# %%
plt.imshow(mask[21])

# %%
plt.imshow(image[21].permute(1,2,0))

# %% [markdown]
# ## U-Net

# %%
# !pip install -q -U segmentation-models-pytorch albumentations > /dev/null
import segmentation_models_pytorch as smp

# %%
model = smp.Unet(
    encoder_name="resnet50",  # Choose an encoder architecture, e.g., "resnet34", "resnet50", "densenet121", etc.
    encoder_weights=None,  # Pretrained weights for the encoder, "imagenet" or None
    in_channels=3,  # Number of input channels
    classes=49,  # Number of output classes
).to(device)

# %%
epochs = 15
criterion = smp.losses.DiceLoss('multiclass').to(device)
optimizer = torch.optim.Adam([
    dict(params=model.parameters(), lr=0.00008),
])

# %%
best_val_loss = 10000.0
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    # Training loop
    model.train()
    train_loss = 0.0
    for images, masks in train_dataloader:
        images, masks = images.to(device), masks.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, masks)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    train_loss /= len(train_dataloader)
    print(f"Train Loss: {train_loss:.4f}")

    # Validation loop
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for images, masks in val_dataloader:
            images, masks = images.to(device), masks.to(device)

            outputs = model(images)
            loss = criterion(outputs, masks)

            val_loss += loss.item()

    val_loss /= len(val_dataloader)
    print(f"Validation Loss: {val_loss:.4f}")
    if val_loss<best_val_loss:
      print("best iter so far\n")
      best_val_loss = val_loss
      model_state_dict = model.state_dict(),
      optimizer_state_dict = optimizer.state_dict()
# Out:
# Epoch 1/15
# Train Loss: 0.8915
# Validation Loss: 0.8335
# best iter so far
#
# Epoch 2/15

# %%
torch.save(model.state_dict(), "simple_model.pt")

# %%
#0.128

# %% [markdown]
# ## Model inference

# %%
# Load the model architecture
model = smp.Unet(
    encoder_name="resnet50",  # Choose an encoder architecture, e.g., "resnet34", "resnet50", "densenet121", etc.
    encoder_weights=None,  # Pretrained weights for the encoder, "imagenet" or None
    in_channels=3,  # Number of input channels
    classes=49,  # Number of output classes
).to(device)

# %%
# Load model weights
model.load_state_dict(torch.load("/content/drive/MyDrive/image_segmentation/simple_model.pt")[0])
# Out:
# <All keys matched successfully>

# %%
# Get the data
# !unzip /content/drive/MyDrive/image_segmentation/hidden_set_for_leaderboard_1.zip

# %%
# Create data loader with sorted list of videos
test_path = '/content/hidden'
test_data = []
for video_nm in tqdm(os.listdir(test_path)):
  test_data.append(os.path.join(test_path, video_nm))
test_data = sorted(test_data, key = (lambda x:int(x.split('_')[-1])))
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
# Test dataloader
class UNetDatasetTest(Dataset):
    def __init__(self, video_list, transform1=None):
        self.video_list = video_list
        self.transform1 = transform1

    def __len__(self):
        return len(self.video_list)

    def __getitem__(self, idx):
        video_path = self.video_list[idx]
        img_name = os.path.join(video_path, 'image_10.png')
        image = Image.open(img_name).convert("RGB")

        # Resize for UNet model
        image_np = np.array(image)
        image_np = cv2.copyMakeBorder(image_np, top=0, bottom=0, left=0, right=16, borderType=cv2.BORDER_CONSTANT, value=0)

        if self.transform1:
            image = self.transform1(Image.fromarray(image_np))
        return image, img_name

# %%
# transforms
transform_test = transforms.Compose([
    transforms.ToTensor(),  # Convert image to tensor
])

# %%
# test loader
batch_size = 32
dataset = UNetDatasetTest(test_data, transform_test)
test_dataloader = DataLoader(dataset, batch_size=batch_size, num_workers=4, shuffle=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
# Model inference
model.eval()
test_loss = 0
correct = 0
total = 0
result = []
criterion = smp.losses.DiceLoss('multiclass').to(device)

# Iterate over the test dataset
with torch.no_grad():
    for data, dir in tqdm(test_dataloader):
        # Perform a forward pass through the model
        data = data.to(device)
        output = model(data)
        _, predicted = torch.max(output.data, 1)
        predicted = predicted[:,:,0:240]
        result.append(predicted)
# Out:
#   0%|          | 0/63 [00:00<?, ?it/s]

# %%
predictions = torch.cat(result, dim = 0)

# %%
torch.save(predictions, 'predictions.pt')

# %%
plt.imshow(predictions[0,:,:].to('cpu'))

# %%
plt.imshow(Image.open(os.path.join(test_data[0], 'image_10.png')).convert('RGB'))

# %%
predictions = predictions.to(device)
jaccard = torchmetrics.JaccardIndex(task="multiclass", num_classes=49).to(device)
jaccard(predictions[0], predictions[0])
# Out:
# tensor(0.0816, device='cuda:0')
